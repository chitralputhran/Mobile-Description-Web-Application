# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_excel("Mobile Data.xlsx")

# %%
data.head()
# Out:
#             DeviceName  Brand   technology      gprs      edge  \
# 0         Apple iPhone  Apple          GSM       Yes       Yes
# 1      Apple iPhone 3G  Apple   GSM / HSPA       Yes       Yes
# 2     Apple iPhone 3GS  Apple   GSM / HSPA       Yes       Yes
# 3       Apple iPhone 4  Apple   GSM / HSPA  Class 10  Class 10
# 4  Apple iPhone 4 CDMA  Apple  CDMA / EVDO        No        No
#
#                             announced                              status  \
# 0  2007, January. Released 2007, June                        Discontinued
# 1     2008, June. Released 2008, July                        Discontinued
# 2     2009, June. Released 2009, June                        Discontinued
# 3                          2010, June      Available. Released 2010, June
# 4                       2011, January  Available. Released 2011, February
#
#                                        dimensions           weight        sim  \
# ...

# %%
data.columns
# Out:
# Index(['DeviceName', 'Brand', 'technology', 'gprs', 'edge', 'announced',
#        'status', 'dimensions', 'weight', 'sim', 'type', 'size', 'resolution',
#        'display_c', 'card_slot', 'alert_types', 'loudspeaker_', 'sound_c',
#        'wlan', 'bluetooth', 'gps', 'radio', 'usb', 'messaging', 'browser',
#        'java', 'features_c', 'battery_c', 'stand_by', 'talk_time', 'colors',
#        'memory_c', 'cpu', 'internal', 'os', 'primary_', 'video', 'secondary',
#        'speed', 'chipset', '_2g_bands', '_3_5mm_jack_', '_3g_bands'],
#       dtype='object')

# %%
from pandas.io import sql

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql://root:password@localhost/mobile_phones?charset=utf8&use_unicode=1")

# %%
con = engine.connect()

# %%
data[data.columns[:10]].to_sql(con = con, name = 'devices', if_exists= 'replace')
